# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('vgsales/vgsales.csv')
df.head(10)
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# ...

# %% [markdown]
# ## 1. Which company is the most common video game publisher?

# %%
most_common_publisher = df['Publisher'].value_counts().idxmax()
most_common_publisher
# Out:
# 'Electronic Arts'

# %% [markdown]
# ## 2. What’s the most common platform?

# %%
most_common_platform = df['Platform'].value_counts().idxmax()
most_common_platform
# Out:
# 'DS'

# %% [markdown]
# ## 3. What about the most common genre?

# %%
most_common_genre = df['Genre'].value_counts().idxmax()
most_common_genre
# Out:
# 'Action'

# %% [markdown]
# ## 4. What are the top 20 highest grossing games?

# %%
top_twenty_highest_grossing_games = df.sort_values('Global_Sales', ascending=False).head(20)
top_twenty_highest_grossing_games
# Out:
#     Rank                                          Name Platform    Year  \
# 0      1                                    Wii Sports      Wii  2006.0
# 1      2                             Super Mario Bros.      NES  1985.0
# 2      3                                Mario Kart Wii      Wii  2008.0
# 3      4                             Wii Sports Resort      Wii  2009.0
# 4      5                      Pokemon Red/Pokemon Blue       GB  1996.0
# 5      6                                        Tetris       GB  1989.0
# 6      7                         New Super Mario Bros.       DS  2006.0
# 7      8                                      Wii Play      Wii  2006.0
# 8      9                     New Super Mario Bros. Wii      Wii  2009.0
# 9     10                                     Duck Hunt      NES  1984.0
# 10    11                                    Nintendogs       DS  2005.0
# 11    12                                 Mario Kart DS       DS  2005.0
# ...

# %% [markdown]
# ## 5. For North American video game sales, what’s the median?
# * Provide a secondary output showing ten games surrounding the median sales output
# * assume that games with same median value are sorted in descending order

# %%
na_median = df['NA_Sales'].median()
print(na_median)

# games_around_median = df[df['NA_Sales'] == na_median]
# games_around_median.head(10)
df.iloc[(df['NA_Sales']- na_median).abs().argsort()[:11]]
# [midpoint_na_sales-5: midpoint_na_sales+5]
# Out:
# 0.08
#         Rank                                          Name Platform    Year  \
# 8428    8430                                      Payday 2     XOne  2015.0
# 11386  11388                                 Sushi Academy       DS  2009.0
# 10491  10493                                       Syberia       XB  2003.0
# 5803    5805    The Legend of Heroes: Trails of Cold Steel      PSV  2013.0
# 3186    3188                                SingStar Queen      PS2  2009.0
# 11390  11392  Super Robot Taisen OG Saga: Endless Frontier       DS  2008.0
# 11403  11405       My English Coach: Para Hispanoparlantes       DS  2009.0
# 8141    8143          Pirates: Hunt For Blackbeard's Booty      Wii  2008.0
# 10463  10465      Tom Clancy's Splinter Cell: Chaos Theory       GC  2005.0
# 10461  10463              Metal Arms: Glitch in the System       GC  2003.0
# 10445  10447                                  Metal Slug 3       XB  2004.0
#
# ...

# %% [markdown]
# ## 6. For the top-selling game of all time, how many standard deviations above/below the mean are its sales for North America?

# %%
top_game = df['Global_Sales'].max()

top_game_mean = df.nlargest(1, 'Global_Sales')
mean = top_game_mean.mean()['NA_Sales']

std = df['NA_Sales'].std()

z_scores = (top_game - mean) / std
print(z_scores)
# Out:
# 50.50919208571411

# %% [markdown]
# ## 7. The Nintendo Wii seems to have outdone itself with games. How does its average number of sales compare with all of the other platforms?

# %%
# wii_of_sales = wii_avg / (wii_avg + others_avg)

wii_sales  = df.loc[df['Platform'] == 'Wii']
wii_average = wii_sales['Global_Sales'].mean()


not_wii_sales = df.loc[df['Platform'] != 'Wii']
not_wii_average = not_wii_sales['Global_Sales'].mean()

wii_of_sales = wii_average / (wii_average + not_wii_average)
wii_of_sales
# Out:
# 0.5719721457080446

# %% [markdown]
# ## 8. Come up with 3 more questions that can be answered with this data set.¶

# %% [markdown]
# ### What is the total global sales for all games?

# %%
total_global_sales = df.Global_Sales.sum()
total_global_sales
# Out:
# 8920.44

# %% [markdown]
# ### What is the total sales for Europe?

# %%
total_EU_sales = df.EU_Sales.sum()
total_EU_sales
# Out:
# 2434.1299999999997

# %% [markdown]
# ### What is the most popular platform in Japan?

# %%
JP_popular = df.JP_Sales.groupby(df.Platform).sum().idxmax()
JP_popular
# Out:
# 'DS'

# %%
def test():

    def assert_equal(actual,expected):
        assert actual == expected, f"Expected {expected} but got {actual}"

    assert_equal(most_common_publisher, 'Electronic Arts')
    assert_equal(most_common_platform, 'DS')
    assert_equal(most_common_genre, 'Action')
    assert_equal(top_twenty_highest_grossing_games.iloc[0].Name, 'Wii Sports')
    assert_equal(top_twenty_highest_grossing_games.iloc[19].Name, 'Brain Age: Train Your Brain in Minutes a Day')
    assert_equal(na_median, 0.08)
    assert_equal(total_global_sales, 8920.44)
    assert_equal(total_EU_sales, 2434.1299999999997)
    assert_equal(JP_popular, 'DS')




    print("Success!!!")

test()
# Out:
# Success!!!
